# %%
import os
os.chdir(f"../../..")
from SOURCE.CLASS_CODE_GPU_Classes import *
from SOURCE.CLASS_CODE_Image_Manager import *
import numpy as np
import json
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display
from time import time
import h5py

# %%
# Set the PARAMETERS ############################################
##################################################################
experiment_name="Basler_like_R0_300x_w0_300x_Z_50x_64bit"
N_R0 = 5
N_w0 = 5
N_Z = 2

output_directory=f"./OUTPUT/LIBRARIES_OF_THEORETICAL_D/{experiment_name}/"
#os.chdir(f"/home/oiangu/Desktop/Conical_Refraction_Polarimeter/")

randomization_seed=666
image_shortest_side=int(540/3)
saturation=1

# Ring parameters to test (each will be a different simulation)
#phiCR_s=np.linspace(-180,180,360*10**significant_decimal+1)*np.pi/180
R0_s=np.linspace(70, 180, N_R0)/3 #np.linspace(70,180,40) # in pxels 153
w0_s=np.linspace( 8, 50, N_w0)/3 #np.linspace(8,50,40) 11
Z_s=np.linspace(0, 1, N_Z)/3
rho_0s=R0_s/w0_s


resolution_side_nx=image_shortest_side # generated images will be resolution_side x resolution_side
# Other parameters
max_k=50
num_k=1200
sim_chunk_ax=image_shortest_side



##################################################
##################################################

# General considerations
image_directory=f"{output_directory}/SIMULATIONS/" #nx_{image_shortest_side}_depth_{image_depth}_sat_{saturation}
os.makedirs(image_directory, exist_ok=True)
np.random.seed(randomization_seed)

# %%
# Initialize the vigilant
try:
    phase_vigilant = json.load(open(f"{output_directory}/STRUCTURE_Grid.json"))
except:
    phase_vigilant = {'R0s':[], 'w0s':[], 'Zs':[], 'IDs':[]}

# Set the objects ready ##################
# The simulator object
simulator=RingSimulator_Optimizer_GPU( n=1.5, a0=1.0, max_k=max_k, num_k=num_k, nx=resolution_side_nx, sim_chunk_x=sim_chunk_ax, sim_chunk_y=sim_chunk_ax)

# Initialize the hdf5 dataset saver
h5f = h5py.File(f"{image_directory}.h5", 'w')

# save phis
h5f.create_dataset('phis', data=simulator.phis[:,:,0], compression="lzf", shuffle=True) #, compression_opts=9)


# Execute the stuff #####################
i=1
total=Z_s.shape[0]*R0_s.shape[0]*w0_s.shape[0]
elapsed=0
beg=time()
output_info_every=100
dump_every=10000

for Z in Z_s:
    for R0 in R0_s:
        for w0 in w0_s:
            ID=f"R0_{R0}_w0_{w0}_Z_{Z}"
            if ID not in phase_vigilant['IDs']:
                # simulate matrix
                D_matrix = simulator.compute_pieces_for_I_LP(R0_pixels=R0, Z=Z, w0_pixels=w0)
                
                if D_matrix is None:
                    raise ValueError
                    
                # save the matrix
                h5f.create_dataset(ID, data=D_matrix, compression="lzf", shuffle=True) #, compression_opts=9)

                #append the data
                phase_vigilant['IDs'].append(ID)
                phase_vigilant['R0s'].append(float(R0))
                phase_vigilant['Zs'].append(float(Z))
                phase_vigilant['w0s'].append(float(w0))
                
                
                if i%output_info_every==0:
                    display.clear_output(wait=True)
                    elapsed=time()-beg
                    print(f"["+'#'*(int(100*i/total))+' '*(100-int(100*i/total))+f"] {100*i/total:3.4}% \n\nSimulated: {i}/{total}\nElapsed time: {elapsed//3600} h {elapsed//60-(elapsed//3600)*60} min {elapsed-(elapsed//60)*60-(elapsed//3600)*60:2.4} s")
                    if i%dump_every==0:
                        # we save the progess (in order to be able to quit and resume)
                        json.dump(phase_vigilant, open( f"{output_directory}/STRUCTURE_Grid.json", "w"))
            i+=1
h5f.close()
print("\n\nFINISHED!!!")
# Out:
# 2021-12-09 19:19:02.509948: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.533429: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.555352: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.578463: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.603973: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.627789: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.651468: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.674152: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.699829: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.729982: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.761236: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.785530: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.840782: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.897983: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:02.963149: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.029872: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.057107: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.081562: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.109275: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.136297: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.160826: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.186332: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.212363: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.235478: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.258187: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.282740: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.311026: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.339416: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:03.371258: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:05.074909: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:05.159026: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:05.172580: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:05.240308: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:05.242561: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:07.015946: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2021-12-09 19:19:07.089740: W external/org_tensorflow/tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# FINISHED!!!

# %%
ID
# Out:
# 'R0_60.0_w0_16.666666666666668_Z_0.3333333333333333'

# %%
t=time()
h5f = h5py.File(f"{image_directory}.h5",'r')
D_mat = h5f[ID][:]
phis = h5f['phis'][:]
#print(list(h5f.keys()))
h5f.close()
print(f"hf5:{time()-t}s size {os.path.getsize(image_directory+'.h5')}")   
print(phis.dtype, phis.shape)
# Out:
# <HDF5 file ".h5" (mode r)>
# hf5:0.0029730796813964844s size 10295460
# <Closed HDF5 file>

# %%
905693/4
# Out:
# 226423.25

# %%
os.path.getsize(image_directory+'.h5')/total
# Out:
# 205909.2

# %%
import pickle, gzip, lzma, bz2
import h5py


# Initialize the vigilant
try:
    phase_vigilant = json.load(open(f"{output_directory}/STRUCTURE_Grid.json"))
except:
    phase_vigilant = {'R0s':[], 'w0s':[], 'Zs':[], 'IDs':[], 'rel_path':[]}

# Set the objects ready ##################
# The simulator object
simulator=RingSimulator_Optimizer_GPU( n=1.5, a0=1.0, max_k=max_k, num_k=num_k, nx=resolution_side_nx, sim_chunk_x=sim_chunk_ax, sim_chunk_y=sim_chunk_ax)

# Execute the stuff #####################
i=1
total=Z_s.shape[0]*R0_s.shape[0]*w0_s.shape[0]
elapsed=0
beg=time()
output_info_every=100
dump_every=10000

for Z in Z_s:
    for R0 in R0_s:
        for w0 in w0_s:
            ID=f"R0_{R0}_w0_{w0}_Z_{Z}"
            if ID not in phase_vigilant['IDs']:
                # simulate matrix
                #D_matrix = simulator.compute_D_matrix( R0_pixels=R0, Z=Z, w0_pixels=w0)
                D_matrix = simulator.compute_pieces_for_I_LP(R0_pixels=R0, Z=Z, w0_pixels=w0)
                
                # save the matrix
                rel_path=f"{image_directory}/{ID}.pkl.lzma"
                #np.save( rel_path, D_matrix, allow_pickle=False)
                print(f"\nDUMP {i}")
                t=time()
                pickle.dump(D_matrix, lzma.open(rel_path, 'wb'))
                print(f"lzma:{time()-t}s size {os.path.getsize(rel_path)}")
                t=time()
                pickle.dump(D_matrix, gzip.open(rel_path+".gzip", 'wb'))
                print(f"gzip:{time()-t}s size {os.path.getsize(rel_path+'.gzip')}")
                t=time()
                pickle.dump(D_matrix, bz2.open(rel_path+".bz2", 'wb'))
                print(f"bz2:{time()-t}s size {os.path.getsize(rel_path+'.bz2')}")
                t=time()
                fp = np.memmap(rel_path+".p", dtype='complex64', mode='w+', shape=(4,180,180))
                fp=D_matrix
                print(f"memmap:{time()-t}s size {os.path.getsize(rel_path+'.p')}")
                t=time()
                h5f = h5py.File(rel_path+'.h5', 'w')
                h5f.create_dataset('dataset_1', data=D_matrix, compression="lzf", shuffle=True) #, compression_opts=9)
                h5f.close()
                print(f"hf5 lzf:{time()-t}s size {os.path.getsize(rel_path+'.h5')}")     


                
                print(f"\nLOAD {i}")
                t=time()
                D_mat=pickle.load(lzma.open(rel_path, 'rb'))
                print(f"lzma:{time()-t}s size {os.path.getsize(rel_path)}")
                t=time()
                D_mat=pickle.load(gzip.open(rel_path+".gzip", 'rb'))
                print(f"gzip:{time()-t}s size {os.path.getsize(rel_path+'.gzip')}")
                t=time()
                D_mat=pickle.load( bz2.open(rel_path+".bz2",'rb'))
                #print(D_mat.dtype, D_mat.shape)
                print(f"bz2:{time()-t}s size {os.path.getsize(rel_path+'.bz2')}")     
                t=time()
                D_mat= np.memmap(rel_path+".p", dtype='complex64', mode='r+', shape=(4,180,180))
                print(f"memmap:{time()-t}s size {os.path.getsize(rel_path+'.p')}")     
                t=time()
                h5f = h5py.File(rel_path+'.h5','r')
                D_mat = h5f['dataset_1'][:]
                h5f.close()
                print(f"hf5:{time()-t}s size {os.path.getsize(rel_path+'.h5')}")     
                print(type(D_mat), D_mat.dtype, D_mat.shape)
                print(np.allclose(D_mat, D_matrix))

                

                if D_matrix is None:
                    raise ValueError

                #append the data
                phase_vigilant['IDs'].append(ID)
                phase_vigilant['R0s'].append(float(R0))
                phase_vigilant['Zs'].append(float(Z))
                phase_vigilant['w0s'].append(float(w0))
                phase_vigilant['rel_path'].append(rel_path)
                
                
                if i%output_info_every==0:
                    display.clear_output(wait=True)
                    elapsed=time()-beg
                    print(f"["+'#'*(int(100*i/total))+' '*(100-int(100*i/total))+f"] {100*i/total:3.4}% \n\nSimulated: {i}/{total}\nElapsed time: {elapsed//3600} h {elapsed//60-(elapsed//3600)*60} min {elapsed-(elapsed//60)*60-(elapsed//3600)*60:2.4} s")
                    if i%dump_every==0:
                        # we save the progess (in order to be able to quit and resume)
                        json.dump(phase_vigilant, open( f"{output_directory}/STRUCTURE_Grid.json", "w"))
            i+=1
print("\n\nFINISHED!!!")
# Out:
# DUMP 1
# lzma:0.10058212280273438s size 102340
# gzip:0.008575677871704102s size 155722
# bz2:0.019051313400268555s size 133046
# memmap:0.00029397010803222656s size 1036800
# hf5 lzf:0.00263214111328125s size 188019
#
# LOAD 1
# lzma:0.006185054779052734s size 102340
# gzip:0.0016970634460449219s size 155722
# bz2:0.01105499267578125s size 133046
# memmap:8.392333984375e-05s size 1036800
# hf5:0.001087188720703125s size 188019
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 2
# lzma:0.09974026679992676s size 102104
# gzip:0.010133028030395508s size 153428
# bz2:0.018419981002807617s size 134295
# memmap:0.0002295970916748047s size 1036800
# hf5 lzf:0.0027184486389160156s size 189092
#
# LOAD 2
# lzma:0.0060346126556396484s size 102104
# gzip:0.0016674995422363281s size 153428
# bz2:0.010317087173461914s size 134295
# memmap:0.00021409988403320312s size 1036800
# hf5:0.0009489059448242188s size 189092
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 3
# lzma:0.10077142715454102s size 100620
# gzip:0.011615514755249023s size 151198
# bz2:0.018389225006103516s size 131093
# memmap:0.0002446174621582031s size 1036800
# hf5 lzf:0.002694368362426758s size 197045
#
# LOAD 3
# lzma:0.005803108215332031s size 100620
# gzip:0.001691579818725586s size 151198
# bz2:0.011022806167602539s size 131093
# memmap:8.463859558105469e-05s size 1036800
# hf5:0.00103759765625s size 197045
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 4
# lzma:0.10017180442810059s size 98516
# gzip:0.009254693984985352s size 150738
# bz2:0.017518281936645508s size 127753
# memmap:0.00023245811462402344s size 1036800
# hf5 lzf:0.002866983413696289s size 202459
#
# LOAD 4
# lzma:0.0057239532470703125s size 98516
# gzip:0.0016891956329345703s size 150738
# bz2:0.010689020156860352s size 127753
# memmap:8.7738037109375e-05s size 1036800
# hf5:0.001123666763305664s size 202459
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 5
# lzma:0.09847545623779297s size 100708
# gzip:0.008804559707641602s size 158233
# bz2:0.01750946044921875s size 135038
# memmap:0.00033354759216308594s size 1036800
# hf5 lzf:0.0028426647186279297s size 209527
#
# LOAD 5
# lzma:0.005917787551879883s size 100708
# gzip:0.0016598701477050781s size 158233
# bz2:0.011018037796020508s size 135038
# memmap:8.296966552734375e-05s size 1036800
# hf5:0.0009577274322509766s size 209527
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 6
# lzma:0.09894418716430664s size 102620
# gzip:0.008311271667480469s size 156247
# bz2:0.018070697784423828s size 133251
# memmap:0.0002846717834472656s size 1036800
# hf5 lzf:0.002793550491333008s size 189107
#
# LOAD 6
# lzma:0.006058692932128906s size 102620
# gzip:0.0016865730285644531s size 156247
# bz2:0.010959148406982422s size 133251
# memmap:8.249282836914062e-05s size 1036800
# hf5:0.001131296157836914s size 189107
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 7
# lzma:0.09923934936523438s size 101924
# gzip:0.009686708450317383s size 154479
# bz2:0.018442153930664062s size 133994
# memmap:0.00028061866760253906s size 1036800
# hf5 lzf:0.0028257369995117188s size 195792
#
# LOAD 7
# lzma:0.005965709686279297s size 101924
# gzip:0.0016541481018066406s size 154479
# bz2:0.010530710220336914s size 133994
# memmap:0.00017452239990234375s size 1036800
# hf5:0.0010075569152832031s size 195792
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 8
# lzma:0.09929203987121582s size 101288
# gzip:0.010396242141723633s size 154619
# bz2:0.020809173583984375s size 135125
# memmap:0.0002932548522949219s size 1036800
# hf5 lzf:0.0029239654541015625s size 199521
#
# LOAD 8
# lzma:0.006990671157836914s size 101288
# gzip:0.0019941329956054688s size 154619
# bz2:0.011434793472290039s size 135125
# memmap:0.00024962425231933594s size 1036800
# hf5:0.0011827945709228516s size 199521
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
#
# DUMP 9
# lzma:0.09902548789978027s size 100072
# gzip:0.008524656295776367s size 154778
# bz2:0.01727581024169922s size 132816
# memmap:0.0003771781921386719s size 1036800
# hf5 lzf:0.0028426647186279297s size 209969
#
# LOAD 9
# lzma:0.005776643753051758s size 100072
# gzip:0.001651763916015625s size 154778
# bz2:0.010457754135131836s size 132816
# memmap:0.00018477439880371094s size 1036800
# hf5:0.001031637191772461s size 209969
# <class 'numpy.ndarray'> float32 (2, 180, 180)
# True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16877/2128859216.py in <module>
#      28                 # simulate matrix
#      29                 #D_matrix = simulator.compute_D_matrix( R0_pixels=R0, Z=Z, w0_pixels=w0)
# ---> 30                 D_matrix = simulator.compute_pieces_for_I_LP(R0_pixels=R0, Z=Z, w0_pixels=w0)
#      31
#      32                 # save the matrix
#
# ~/Desktop/Conical_Refraction_Polarimeter/SOURCE/CLASS_CODE_GPU_Classes.py in compute_pieces_for_I_LP(self, R0_pixels, Z, w0_pixels)
#     202         return compute_D_matrix_raw(self.B0, self.B1, self.sin_phis, self.cos_phis)
#     203     def compute_pieces_for_I_LP(self, R0_pixels, Z, w0_pixels):
# --> 204         self._compute_B0_B1(Z, R0_pixels, w0_pixels)
#     205         return pieces_for_I_LP(self.B0, self.B1) #, self.phis[:,:,0])
#     206
#
# ~/Desktop/Conical_Refraction_Polarimeter/SOURCE/CLASS_CODE_GPU_Classes.py in _compute_B0_B1(self, Z, R0, w0)
#     188                 compute_B0_block( self.n, self.a0, R0/w0, rs_block, self.ks, Z, self.dk, jax.device_put(j0(self.ks*rs_block))  ))#[ny, nx, 1]
#     189                 self.B1=self.B1.at[ self.chunks_x[ix]:self.chunks_x[ix+1], self.chunks_y[iy]:self.chunks_y[iy+1]].set(
# --> 190                 compute_B1_block( self.n, self.a0, R0/w0, rs_block, self.ks, Z, self.dk, jax.device_put(j1(self.ks*rs_block))  ))  #[ny, nx, 1]
#     191
#     192     def _compute_D_and_Intensity_Turpin(self, in_polrz): # This is rather very fast
#
# KeyboardInterrupt:

# %%
# %%time
for i in range(1000):
    a=np.abs(D_mat)**2

# %%
# %%time
for i in range(1000):
    a=(D_mat*D_mat.conjugate()).real

# %%
# %%time
for i in range(1000):
    a=D_mat.real**2+D_mat.imag**2

# %%
# %%time
for i in range(1000):
    a=D_mat.real**2
    a+=D_mat.imag**2

# %%
np.allclose( (D_mat*D_mat.conjugate()).real, D_mat.real**2+D_mat.imag**2, rtol=0)
